# %%
import pandas as pd

# %%
model = 'Campbell_Bozorgnia_2014'

# %%
for site in range(961): 

    ims = pd.read_csv(f'./{model}/Output/IMs/site{site}.csv')
    ims = ims[['PGA']]

    ims.to_csv(f'./{model}/Output/IMs/site{site}.csv', index = False)
