# %%
import pandas as pd

# %%
model = 'Chiou_Youngs_2014'

# %%
for site in range(961): 

    ims = pd.read_csv(f'/Users/mialochhead/Desktop/GROUND_MOTIONS/{model}/Output/IMs/site{site}.csv')
    ims = ims[['PGA']]

    ims.to_csv(f'/Users/mialochhead/Desktop/GROUND_MOTIONS/{model}/Output/IMs/site{site}.csv', index = False)
